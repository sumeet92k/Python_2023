# %% [markdown]
# # Types of Machine Learning problems

# %% [markdown]
# ![sklearn_ML_types.png](attachment:sklearn_ML_types.png)
# https://scikit-learn.org/stable/tutorial/machine_learning_map/index.

# %% [markdown]
# ## Supervised vs. Unsupervised learning
# ![wiki_ML_supervised_vs_unsupervised.png](attachment:wiki_ML_supervised_vs_unsupervised.png)
# https://commons.wikimedia.org/wiki/File:Supervised_and_unsupervised_machine_learning.webp

# %% [markdown]
# <!-- ## Supervised vs. Unsupervised learning
# <div>
# <img src="attachment:image-2.png" width="600"/>
# </div> -->

# %% [markdown]
# # Start of ML

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
sns.set_style(style='darkgrid')

# %%
df = pd.read_csv('07_USA_Housing.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Exploratory data analysis

# %%
df.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
df.tail()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 4995                          3.46     22837.361035  1.060194e+06
# 4996                          4.02     25616.115489  1.482618e+06
# 4997                          2.13     33266.145490  1.030730e+06
# 4998                          5.44     42625.620156  1.198657e+06
# 4999                          4.07     46501.283803  1.298950e+06
#
#                                                 Address
# 4995                   USNS Williams\nFPO AP 30153-7653
# ...

# %%
df.sample(5)
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 265       57477.950762             5.405445                   7.207173
# 3759      74030.615553             4.723381                   5.573092
# 959       70564.862576             5.146618                   6.597994
# 3249      72662.613141             8.190793                   6.140355
# 1801      66658.967909             7.729790                   7.130498
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# 265                           6.35     23649.968870  5.687032e+05
# 3759                          2.40     46784.725215  1.194595e+06
# 959                           4.50     38376.468254  1.014226e+06
# 3249                          3.26     33532.539256  1.693694e+06
# 1801                          4.00     57563.585738  1.720734e+06
#
#                                                 Address
# 265   2105 Lauren Radial\nLake Michellestad, FL 9209...
# ...

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df['Price']
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
df[['Avg. Area Income', 'Price']]
# Out:
#       Avg. Area Income         Price
# 0         79545.458574  1.059034e+06
# 1         79248.642455  1.505891e+06
# 2         61287.067179  1.058988e+06
# 3         63345.240046  1.260617e+06
# 4         59982.197226  6.309435e+05
# ...                ...           ...
# 4995      60567.944140  1.060194e+06
# 4996      78491.275435  1.482618e+06
# 4997      63390.686886  1.030730e+06
# 4998      68001.331235  1.198657e+06
# 4999      65510.581804  1.298950e+06
#
# [5000 rows x 2 columns]

# %%
df['Price'].describe()
# Out:
# count    5.000000e+03
# mean     1.232073e+06
# std      3.531176e+05
# min      1.593866e+04
# 25%      9.975771e+05
# 50%      1.232669e+06
# 75%      1.471210e+06
# max      2.469066e+06
# Name: Price, dtype: float64

# %%
df['Price'].hist()
# Out:
# <AxesSubplot:>

# %%
# sns.displot(data=df, x='Price', bins=20)
sns.displot(data=df, x='Price')

# %%
sns.displot(data=df, x='Price', kind='kde')

# %%
sns.histplot(data=df, x='Price', kde=True)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
sns.scatterplot(data=df, x='Avg. Area Number of Rooms', \
                y='Price', hue='Avg. Area Number of Bedrooms')
# Out:
# <AxesSubplot:xlabel='Avg. Area Number of Rooms', ylabel='Price'>

# %%
plt.scatter(x=df['Avg. Area Number of Rooms'], y=df['Price'])

# %% [markdown]
# ## To continue in next class further exploration of this data and linear regression
